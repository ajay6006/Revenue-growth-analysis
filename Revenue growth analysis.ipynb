# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_file.csv',encoding='latin1')

# %%
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4508    4509  US-2014-138247  12/24/2014  12/29/2014  Standard Class
# 6007    6008  CA-2017-129028    4/1/2017    4/3/2017     First Class
# 3123    3124  CA-2015-121720   6/11/2015   6/12/2015     First Class
# 532      533  US-2017-129441    9/7/2017   9/11/2017  Standard Class
# 6351    6352  CA-2017-161130   11/3/2017   11/8/2017  Standard Class
#
#      Customer ID    Customer Name      Segment        Country         City  \
# 4508    BF-11170       Ben Ferrer  Home Office  United States  Los Angeles
# 6007    GB-14530      George Bell    Corporate  United States     Florence
# 3123    JE-15610          Jim Epp    Corporate  United States     Lakeland
# 532     JC-15340  Jasper Cacioppo     Consumer  United States  Los Angeles
# 6351    BF-11275    Beth Fritzler    Corporate  United States        Miami
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Checking data shape i.e No. of rows and columns
df.shape
# Out:
# (9994, 21)

# %%
# Checking descriptive stats
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Converting date columns in a proper format i.e in datetime datatype
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] =pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Created new columns for better analysis
df['Order month'] = df['Order Date'].dt.month
df['Order year'] = df['Order Date'].dt.year
df['Order day of week'] = df['Order Date'].dt.dayofweek

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Order month', 'Order year', 'Order day of week'],
#       dtype='object')

# %% [markdown]
# ### Q1. Calculate the monthly sales of the store and identify which month had the highest sales and which month had the lowest sales.

# %%
sales_by_month =df.groupby('Order month')['Sales'].sum()
sales_by_month
# Out:
# Order month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,4))
plt.plot(sales_by_month)
plt.title('Sales by Month',size=15)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Q2. analyze sales based on product categories and determine which category has the lowest sales and which category has the highest sales.

# %%
Sales_by_Category = df.groupby('Category')['Sales'].sum()
plt.title('Category wise sales',size=15)
plt.pie(Sales_by_Category, labels=Sales_by_Category.index, autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Q.3 sales analysis needs to be done based on sub-categories

# %%
Sales_by_subcategory = df.groupby('Sub-Category')['Sales'].sum()
Sales_by_subcategory = Sales_by_subcategory.sort_values(ascending=False)  # Sort in descending order
Sales_by_subcategory
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.title('Sub-Category wise Sales',size=15)
sns.barplot(Sales_by_subcategory)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q.4 analyze the monthly profit from sales and determine which month had the highest profit.

# %%
profit_by_month = df.groupby('Order month')['Profit'].sum()
profit_by_month
# Out:
# Order month
# 1      9134.4461
# 2     10294.6107
# 3     28594.6872
# 4     11587.4363
# 5     22411.3078
# 6     21285.7954
# 7     13832.6648
# 8     21776.9384
# 9     36857.4753
# 10    31784.0413
# 11    35468.4265
# 12    43369.1919
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12,4))
plt.title('Profit per month',size=15)
sns.lineplot(profit_by_month,color = 'darkblue')
plt.show()

# %% [markdown]
# ### Q.5 Analyze the profit by category and sub-category.

# %%
profit_by_Category = df.groupby('Category')['Profit'].sum()
profit_by_Category
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
Profit_by_Category = df.groupby('Category')['Profit'].sum()
plt.title('Category wise Profit',size=15)
plt.pie(Profit_by_Category, labels=Profit_by_Category.index, autopct='%1.2f%%')
plt.show()

# %%
profit_by_SubCategory = df.groupby('Sub-Category')['Profit'].sum()
profit_by_SubCategory
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.title('Sub-Category wise Profit',size=15)
sns.barplot(profit_by_SubCategory)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q.6 Analyze the sales to profit ratio by customer segment

# %%
Sales_by_segment = df.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).round(2)
Sales_by_segment
# Out:
#                   Sales     Profit
# Segment
# Consumer     1161401.34  134119.21
# Corporate     706146.37   91979.13
# Home Office   429653.15   60298.68

# %%
Profit_Sales_Ratio = (Sales_by_segment['Sales']/Sales_by_segment['Profit']).round(2)
Profit_Sales_Ratio
# Out:
# Segment
# Consumer       8.66
# Corporate      7.68
# Home Office    7.13
# dtype: float64
